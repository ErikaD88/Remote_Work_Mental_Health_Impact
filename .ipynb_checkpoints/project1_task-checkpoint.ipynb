# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt

# Read Remote Work and Mental Health Data File and store into Pandas DataFrames
df = pd.read_csv("Impact_of_Remote_Work_on_Mental_Health.csv")

df.head()
# Out:
#   Employee_ID  Age      Gender           Job_Role    Industry  \
# 0     EMP0001   32  Non-binary                 HR  Healthcare
# 1     EMP0002   40      Female     Data Scientist          IT
# 2     EMP0003   59  Non-binary  Software Engineer   Education
# 3     EMP0004   27        Male  Software Engineer     Finance
# 4     EMP0005   49        Male              Sales  Consulting
#
#    Years_of_Experience Work_Location  Hours_Worked_Per_Week  \
# 0                   13        Hybrid                     47
# 1                    3        Remote                     52
# 2                   22        Hybrid                     46
# 3                   20        Onsite                     32
# 4                   32        Onsite                     35
#
#    Number_of_Virtual_Meetings  Work_Life_Balance_Rating Stress_Level  \
# 0                           7                         2       Medium
# 1                           4                         1       Medium
# ...

# %%
# Filter for North America
asia_data = df[df['Region'] == 'Asia']

# Bin hours worked into ranges
bins = [0, 20, 40, 60, 80]
bin_labels = ['0-20', '21-40', '41-60', '61-80']
asia_data['Hours_Worked_Bins'] = pd.cut(
    asia_data['Hours_Worked_Per_Week'], bins=bins, labels=bin_labels, right=False
)

# Group data by hours worked bins and productivity change
grouped_data = asia_data.groupby(['Hours_Worked_Bins', 'Productivity_Change']).size().unstack(fill_value=0)

# Plot a binned bar chart
grouped_data.plot(kind='bar', figsize=(12, 6), width=0.8, color=['green', 'blue', 'red'])

# Customize the chart
plt.title("Productivity Change vs. Hours Worked Bins (Asia)", fontsize=14)
plt.xlabel("Hours Worked Per Week (Bins)", fontsize=12)
plt.ylabel("Number of Employees", fontsize=12)
plt.xticks(rotation=0)  # Rotate x-axis labels for readability
plt.legend(title="Productivity Change", labels=['Decrease', 'No Change', 'Increase'])

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\pfeeney\AppData\Local\Temp\5\ipykernel_18884\1922226048.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   asia_data['Hours_Worked_Bins'] = pd.cut(
# C:\Users\pfeeney\AppData\Local\Temp\5\ipykernel_18884\1922226048.py:12: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = asia_data.groupby(['Hours_Worked_Bins', 'Productivity_Change']).size().unstack(fill_value=0)

# %%
# Filter for North America
north_america_data = df[df['Region'] == 'North America']
# Bin hours worked into ranges
bins = [0, 20, 40, 60, 80]
bin_labels = ['0-20', '21-40', '41-60', '61-80']
north_america_data['Hours_Worked_Bins'] = pd.cut(
    north_america_data['Hours_Worked_Per_Week'], bins=bins, labels=bin_labels, right=False
)
# Group data by hours worked bins and productivity change
grouped_data = north_america_data.groupby(['Hours_Worked_Bins', 'Productivity_Change']).size().unstack(fill_value=0)
# Plot a binned bar chart
grouped_data.plot(kind='bar', figsize=(12, 6), width=0.8, color=['green', 'blue', 'red'])
# Customize the chart
plt.title("Productivity Change vs. Hours Worked Bins (North America)", fontsize=14)
plt.xlabel("Hours Worked Per Week (Bins)", fontsize=12)
plt.ylabel("Number of Employees", fontsize=12)
plt.xticks(rotation=0)  # Rotate x-axis labels for readability
plt.legend(title="Productivity Change", labels=['Decrease', 'No Change', 'Increase'])
# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\pfeeney\AppData\Local\Temp\5\ipykernel_18884\1235051653.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   north_america_data['Hours_Worked_Bins'] = pd.cut(
# C:\Users\pfeeney\AppData\Local\Temp\5\ipykernel_18884\1235051653.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = north_america_data.groupby(['Hours_Worked_Bins', 'Productivity_Change']).size().unstack(fill_value=0)
